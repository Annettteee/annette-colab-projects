# %% [markdown]
# <a href="https://colab.research.google.com/github/Annettteee/annette-colab-projects/blob/main/EXPLORER_Transportation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚗 **Welcome to my <font color='crimson'>** **Explorer Transportation Data Science Project! 🚗**</font>
#
#
# ---

# %% [markdown]
# ## <font color='crimson'>**Project Information and Background:**</font>

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## <font color='crimson'>**LEARN: An Introduction to Python Programming**</font>

# %% [markdown]
# Python is a programming language often used to analyze data.
#
# Python is open-source, which means it's free to use and distribute, even for commercial purposes. Python's versatility allows it to be used for web development, data visualization, artificial intelligence, scientific computing, and more.
#
# Python's extensive standard library, along with its powerful third-party packages, enable developers and data scientists to perform a vast array of tasks.
#
# For those looking to dive deeper into Python, here are some valuable resources:
# - [The Official Python Documentation](https://docs.python.org/3/) – Offers comprehensive guides and reference materials for Python leaners.
# - [Real Python](https://realpython.com/) – Provides tutorials and articles for Python developers of all skill levels.
# - [PyCon](https://pycon.org/) – The largest annual gathering for the Python community, which is useful for learning from experts and discovering the latest developments in the Python ecosystem.
# - [Python for Everybody](https://www.py4e.com/) – A book and website by Dr. Charles Severance that offers a free course on Python for beginners.

# %% [markdown]
# **Some essential Python Functions!**
#
# Here are some key functions we'll frequently encounter:
#
# 1. **`head()`**: This function is crucial for getting a quick overview of our dataset. By default, it returns the first five rows, offering a snapshot of our data's structure and values.
#
# 2. **`describe()`**: This provides a summary of the statistical characteristics of our dataset. It's particularly useful for gaining insights into the distribution, mean, standard deviation, and range of numerical columns.
#
# 3. **`sum()`**: This calculates the total sum of a column or a series of numbers, proving essential for quick calculations and aggregations in data analysis.
#
# 4. **`isnull()`**: This helps identify missing or null values in our dataset, allowing for effective data cleaning and preprocessing.
#
# 5. **`value_counts()`**: Understanding the frequency of various values in our dataset is a common task in data science. The `value_counts()` function makes this easy by counting the occurrence of each unique value in a column.
#
# Now that we've reviewed these important concepts, let's dive in to the project!

# %% [markdown]
# ## <font color='crimson'>**Data Preparation**</font>
# GOAL: The main goal of this session is to set up our environment, install the required packages, learn how to access data and do some basic exploratory data analysis.

# %% [markdown]
# **Step 1:** Setting up libraries and installing packages
#
# A **library** is a collection of code that we can use in our programs, while a **package** is a folder that contains libraries or other packages, organized for easy use.
#
# To install a library, we'll use the following format:
# ```python
#  import <library name> as <shortname>
# ```
# We use a *short name* since it is easier to refer to the package to access functions and also to refer to subpackages within the library. Think of it as a nickname for easier reference!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# **LEARN:** What each library does:
#
#
#
#
# > * Pandas: Library for manipulationg, cleaning and analyzing data.
# > * Matplotlib: Library for creating visualizations like line plots, bar charts and box plots.
# > * Seaborn: This is a library ofr statistical visualizations like heat maps.

# %% [markdown]
# **Step 2:** Let’s access our data. We will be using the [NYC OpenData Motor Vehicle Collisions - Crashes dataset](https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95). According to NYC Open Data, "each row represents a crash event. The Motor Vehicle Collisions data tables contain information from all police reported motor vehicle collisions in NYC."

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Next, we will read the data using the `pd.read_csv` function.
# Ensure that you've downloaded the dataset from NYC OpenData, and uploaded the dataset to our Google Drive.

# %%
#Read the data using pandas read_csv function
data = pd.read_csv("/content/Motor_Vehicle_Collisions_-_Crashes_20250325.csv")
# Out:
# <ipython-input-73-083f4efac7d6>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/Motor_Vehicle_Collisions_-_Crashes_20250325.csv")

# %% [markdown]
# **Step 3:** Let's see what the data looks like. We can use the `head` function which returns the first 5 rows of the dataset.

# %%
# Print the first 5 rows of the data using head function of pandas
data.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN       NaN       NaN        NaN
# 1  03/26/2022      11:45       NaN       NaN       NaN        NaN
# 2  11/01/2023       1:29  BROOKLYN   11230.0  40.62179 -73.970024
# 3  06/29/2022       6:55       NaN       NaN       NaN        NaN
# 4  09/21/2022      13:21       NaN       NaN       NaN        NaN
#
#                  LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                     NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                     NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2  (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
# 3                     NaN       THROGS NECK BRIDGE               NaN
# 4                     NaN          BROOKLYN BRIDGE               NaN
#
#   OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN  ...                    Unspecified
# 1             NaN  ...                            NaN
# 2             NaN  ...                    Unspecified
# 3             NaN  ...                    Unspecified
# 4             NaN  ...                    Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                    Unspecified                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN     4455765.0
# 1                            NaN     4513547.0
# 2                            NaN     4675373.0
# 3                            NaN     4541903.0
# 4                            NaN     4566131.0
#
#                    VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  \
# 0                                Sedan                Sedan
# 1                                Sedan                  NaN
# 2                                Moped                Sedan
# 3                                Sedan        Pick-up Truck
# 4  Station Wagon/Sport Utility Vehicle                  NaN
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                Sedan                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
distinct_years = data['CRASH DATE'].str.split('/').str[2].unique()
distinct_years
# Out:
# array(['2021', '2022', '2023', '2019', '2020', '2016', '2024', '2012',
#        '2018', '2017', '2013', '2014', '2025'], dtype=object)

# %%
def generate_rows_for_year(df, year):
    """Generates rows for a specific year from the DataFrame.

    Args:
        df: The input DataFrame.
        year: The year to filter for.

    Returns:
        A new DataFrame containing only the rows for the specified year,
        or None if the year is not found.
    """
    try:
        # Convert 'CRASH DATE' to datetime objects if they are not already.
        df['CRASH DATE'] = pd.to_datetime(df['CRASH DATE'], errors='coerce')
        # Extract the year from the 'CRASH DATE' column.
        df['Year'] = df['CRASH DATE'].dt.year

        # Filter the DataFrame to include only rows for the given year
        year_data = df[df['Year'] == int(year)]

        if year_data.empty:
          print(f"No data found for the year {year}")
          return None
        else:
            return year_data

    except KeyError:
        print("'CRASH DATE' column not found in the DataFrame.")
        return None
    except ValueError:
        print("Invalid date format in 'CRASH DATE' column.")
        return None

year_to_filter = 2026
filtered_df = generate_rows_for_year(data, year_to_filter)

if filtered_df is not None:
  print(filtered_df.head())
# Out:
# No data found for the year 2026

# %%
desc_stats = data.describe()
desc_stats
# Out:
#                           CRASH DATE       ZIP CODE       LATITUDE  \
# count                        1075193  697314.000000  995585.000000
# mean   2020-03-08 18:57:03.738807808   10877.097746      40.561846
# min              2012-07-27 00:00:00   10000.000000       0.000000
# 25%              2018-06-24 00:00:00   10454.000000      40.666893
# 50%              2019-09-07 00:00:00   11208.000000      40.718414
# 75%              2021-10-25 00:00:00   11249.000000      40.774853
# max              2025-01-07 00:00:00   11697.000000      41.126150
# std                              NaN     537.382608       2.571647
#
#            LONGITUDE  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# count  995585.000000               1.075178e+06              1.075170e+06
# mean      -73.630587               3.692142e-01              1.789484e-03
# min      -201.237060               0.000000e+00              0.000000e+00
# 25%       -73.968895               0.000000e+00              0.000000e+00
# 50%       -73.922070               0.000000e+00              0.000000e+00
# 75%       -73.864510               1.000000e+00              0.000000e+00
# max         0.000000               4.000000e+01              8.000000e+00
# std         4.795928               7.420914e-01              4.482750e-02
#
#        NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# count                   1.075192e+06                  1.075192e+06
# mean                    6.154529e-02                  8.193885e-04
# min                     0.000000e+00                  0.000000e+00
# 25%                     0.000000e+00                  0.000000e+00
# 50%                     0.000000e+00                  0.000000e+00
# 75%                     0.000000e+00                  0.000000e+00
# max                     2.700000e+01                  6.000000e+00
# std                     2.543501e-01                  2.950935e-02
#
#        NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# count               1.075192e+06              1.075192e+06
# mean                3.415948e-02              1.571812e-04
# min                 0.000000e+00              0.000000e+00
# 25%                 0.000000e+00              0.000000e+00
# 50%                 0.000000e+00              0.000000e+00
# 75%                 0.000000e+00              0.000000e+00
# max                 3.000000e+00              2.000000e+00
# std                 1.844537e-01              1.261019e-02
#
#        NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  COLLISION_ID  \
# count                1.075192e+06               1.075192e+06  1.075192e+06
# mean                 2.661553e-01               7.719551e-04  4.202100e+06
# min                  0.000000e+00               0.000000e+00  3.415658e+06
# 25%                  0.000000e+00               0.000000e+00  3.931653e+06
# 50%                  0.000000e+00               0.000000e+00  4.203016e+06
# 75%                  0.000000e+00               0.000000e+00  4.471896e+06
# max                  4.000000e+01               5.000000e+00  4.783032e+06
# std                  7.057819e-01               3.008803e-02  3.116276e+05
#
#                Year
# count  1.075193e+06
# mean   2.019672e+03
# min    2.012000e+03
# 25%    2.018000e+03
# 50%    2.019000e+03
# 75%    2.021000e+03
# max    2.025000e+03
# std    2.075146e+00

# %% [markdown]
# 1. Latitude & Longitude: The latitude and longitude indicate where the crashes are occurring. However, there are some data points with latitude and longitude values of 0, which is likely due to missing or inaccurate data.
#
# 2. Number of Persons Injured: On average, each crash has around 0.305 injuries. The maximum number of injuries in a single crash is 43.
#
# 3. Number of Persons Killed: Fatalities are rare, with an average of 0.00146 deaths per crash. The maximum number of deaths in one crash is 8.
#
# 4. Number of Pedestrians, Cyclists, and Motorists Injured/Killed: These columns provide a breakdown of the injuries and fatalities by type of individual involved.
#
# 5. Collision ID: This is a unique identifier for each crash.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Data Ethics, Pre-Processing, and Exploration** </font>
# GOAL: The main goal of this session is to assess the dataset, find missing values, and decide what to do with those missing data points.

# %% [markdown]
# **Step 1:**
# Before we begin assessing our data for missing values, it is important that we understand the ethical implications surrounding data processing.

# %% [markdown]
# **Step 2:**
# Check the dataset for missing values.

# %%
#Leverage the isnull() and sum() functions to find the number of missing values in each column
missing_values = data.isnull().sum()

#Turn the missing value counts into percentages
missing_values_percentage = (missing_values / len(data)) * 100

#Return counts and percentages of missing values in each column
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage (%)': missing_values_percentage})
missing_data.sort_values(by='Percentage (%)', ascending=False)
# Out:
#                                Missing Values  Percentage (%)
# VEHICLE TYPE CODE 5                   1069590       99.478884
# CONTRIBUTING FACTOR VEHICLE 5         1069378       99.459167
# VEHICLE TYPE CODE 4                   1055818       98.197998
# CONTRIBUTING FACTOR VEHICLE 4         1054858       98.108712
# VEHICLE TYPE CODE 3                    995785       92.614535
# CONTRIBUTING FACTOR VEHICLE 3          990875       92.157873
# OFF STREET NAME                        804554       74.828798
# CROSS STREET NAME                      557909       51.889196
# ZIP CODE                               377879       35.145225
# BOROUGH                                377702       35.128763
# VEHICLE TYPE CODE 2                    277786       25.835920
# ON STREET NAME                         271768       25.276206
# CONTRIBUTING FACTOR VEHICLE 2          198168       18.430924
# LATITUDE                                79608        7.404066
# LOCATION                                79608        7.404066
# LONGITUDE                               79608        7.404066
# VEHICLE TYPE CODE 1                      9859        0.916952
# CONTRIBUTING FACTOR VEHICLE 1            4549        0.423087
# NUMBER OF PERSONS KILLED                   23        0.002139
# NUMBER OF PERSONS INJURED                  15        0.001395
# NUMBER OF PEDESTRIANS KILLED                1        0.000093
# NUMBER OF PEDESTRIANS INJURED               1        0.000093
# NUMBER OF CYCLIST INJURED                   1        0.000093
# NUMBER OF CYCLIST KILLED                    1        0.000093
# NUMBER OF MOTORIST INJURED                  1        0.000093
# NUMBER OF MOTORIST KILLED                   1        0.000093
# COLLISION_ID                                1        0.000093
# CRASH DATE                                  0        0.000000
# CRASH TIME                                  0        0.000000
# Year                                        0        0.000000

# %% [markdown]
# Here's an overview of the missing values in the dataset:
#
# Columns like VEHICLE TYPE CODE 5, CONTRIBUTING FACTOR VEHICLE 5, VEHICLE TYPE CODE 4, and so on have a high percentage of missing values. This is expected since not all crashes involve multiple vehicles or factors.
#
# OFF STREET NAME and CROSS STREET NAME have significant missing values. This could be due to crashes occurring in locations where these details aren't applicable or weren't recorded.
#
# ZIP CODE, BOROUGH, and ON STREET NAME also have missing values. This might be due to incomplete data entry or crashes occurring in areas where these specifics aren't easily determinable.
#
# LOCATION, LATITUDE, and LONGITUDE have the same count of missing values, indicating that when one is missing, the others are likely missing as well.

# %% [markdown]
# **Step 3:** Create a bar chart to display the top 10 contributing factors (e.g. backing up unsafely, unsafe lane changing, etc.) to crashes within the dataset.

# %%
#Plot a Bar Chart

top_factors = data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)


plt.figure(figsize=(12, 7))
# Plotting the top contributing factors, fill in x as the index field of the variable 'top_factors'
sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")
plt.title('Top 10 Contributing Factors to crashes', fontsize=16)
plt.xlabel('Index of Top Factors', fontsize=14)
plt.ylabel('Values of Top Factors', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-9-42be94d7d108>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")

# %% [markdown]
# **LEARN:** Besides for "Unspecified," what are the top 3 contributing factors that cause the most crashes?
#
# > *  Distractions
# > *  Failure to yield right of way
# > *  Following too closely

# %% [markdown]
# **LEARN:** What recommendations would you make to new and current drivers after assessing the above data?
#
# > *   Concentrate, be kind and generous and follow from a car length away to give you enough reaction time

# %% [markdown]
# **Step 4:** Now, let's create another bar chart to determine which vehicle types were involved in the most crashes.

# %%
# Determine the top vehicle types involved in crashes
top_vehicle_types = data['VEHICLE TYPE CODE 1'].value_counts().head(10)

# Plotting the top vehicle types
plt.figure(figsize=(12, 7))
sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values , palette="cividis")
plt.title('Top 10 Vehicle Types Involved in crashes', fontsize=16)
plt.xlabel('Vehicle Type', fontsize=14)
plt.ylabel('Number of crashes', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-10-cbdfeab34f53>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values , palette="cividis")

# %% [markdown]
# **LEARN** What are the top 3 vehicles that were most involved in crashes?
#
#
# > *   Sedan
# > *   Station wagon
# > *   Passenger vehicle

# %% [markdown]
# **LEARN:** Why do you think that "Sedan[s]," "Station Wagon[s]," and "Passenger Vehicle[s]" are involved in a larger number of crashes, injuries, and deaths when compared to the rest of the vehicles? (Think outside the box!)
#
#
# > *  They are the most common vehicles used. They are also driven by diverse group of people when it comes to age groups and experience. Passenger vehicles mostly carry more than one people resulting in more deaths from one crash.

# %% [markdown]
# **LEARN:** Review the x-axis of the bar chart you created above. </br>
# 1) What do you notice? </br>
# 2) What would you recommend we do to improve the bar chart, based on the x-axis (horizontal axis) and why? </br>
# 3) What recommendation would you make to those who are collecting and/or inputting data into this dataset?
#
#
# > *  1)  I noticed inconsistency in the cases.
# > *  2) Based on the x-axis, we can clean the data and make the cases consistent to improve readability and presentation.
# > *  3) They should try to be consistent with the way they input their data.

# %% [markdown]
# **Step 5:**  A DataFrame is a two-dimensional and potentially heterogeneous tabular data structure with labeled axes (rows and columns). DataFrames allow for storing, manipulating, and retrieving data in a structured form, serving as the primary data structure for a multitude of data processing tasks. It is used with Python libraries like pandas.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Aggregating data - Complete for Cyclist and Motorist
types_of_crashes = {
    'Pedestrian Injuries': data['NUMBER OF PEDESTRIANS INJURED'].sum(),
    'Cyclist Injuries': data['NUMBER OF CYCLIST INJURED'].sum(),
    'Motorist Injuries': data['NUMBER OF MOTORIST INJURED'].sum(),
    'Pedestrian Deaths': data['NUMBER OF PEDESTRIANS KILLED'].sum(),
    'Cyclist Deaths': data['NUMBER OF CYCLIST KILLED'].sum(),
    'Motorist Deaths': data['NUMBER OF MOTORIST KILLED'].sum()
}

# Converting to DataFrame for easier plotting - we want the items in the dictionary, use the items function
crash_types_df = pd.DataFrame(list(types_of_crashes.items()), columns=['crash Type', 'Count'])

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")
plt.title('Types of crashes and Their Frequencies')
plt.xlabel('Count')
plt.ylabel('Type of crash')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-1d14d8e1a468>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")

# %% [markdown]
# **LEARN:** Analyze the chart above. What is a recommendation you might make to the Department of Transportation based on this data?
#
#
# > *  Almost 85 to 90% of the injuries are from motorists followed by pedetrians and then cyclists. I would recommend the Department of transportation to focus more on ways to reduce injuries of roads. Injuries between cyclist. They can hold an open forum or a competition to gather ideas from the public on ways to reduce this. They can also enforce laws related to motorists. For pedestrians, I would recommend enforcing pedestrian crossing laws as well as build pedesrian bridges ro separate pedestrians from motorists.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Time Series Analysis**</font>
# GOAL: The main goal of this session is to dive deeper into Time Series Analysis in order to better understand our data's trends over time.

# %% [markdown]
# **Step 1:**
#
# Understanding the basics, including Trends, Seasonality, and Residual Components.
#
# *  [Learn about Time Series patterns here](https://otexts.com/fpp2/tspatterns.html)
# * [Learn about Time Plots here](https://otexts.com/fpp2/time-plots.html)
# *[Learn how to decompose Time Series Data into Trend and Seasonality](https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/)

# %% [markdown]
# **Step 2:** Creating a chart that displays the average number of crashes per hour of the day. This will help us understand whether additional factors are contributing to crashes - i.e. rush hour, school dismissal time, night fall, etc.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset
file_path = "/content/Motor_Vehicle_Collisions_-_Crashes_20250325.csv"
data = pd.read_csv(file_path)

# Convert 'CRASH DATE' and 'CRASH TIME' to datetime
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])
data['CRASH TIME'] = pd.to_datetime(data['CRASH TIME'], format='%H:%M', errors='coerce')

# Time of Day Analysis
data['Hour of Day'] = data['CRASH TIME'].dt.hour

# Group by 'Hour of Day' and calculate the average number of crashes per hour
average_crashes_per_hour = data.groupby('Hour of Day').size() / data['Hour of Day'].nunique()

# Plot the average number of crashes
plt.figure(figsize=(12, 6))
sns.barplot(x=average_crashes_per_hour.index, y=average_crashes_per_hour.values)
plt.title('Average Number of crashes per Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Average Number of crashes')
plt.xticks(range(0, 24))
plt.show()

# %% [markdown]
# **LEARN:** Which time of the day sees the most crashes? Why do you think so?
#
# > *  4pm sees the most crashes. This is mostly when people are returning from a tired day ar work, at school or reruring from ending their day somewhere. There are also distracting from end of the day plans, checking phones and multitasking.

# %% [markdown]
# **Step 3:**
# Plot a graph to determine how COVID-19 impacted the number of crashes per month, if at all.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert 'CRASH DATE' to datetime format
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# Group by year to get the number of crashes per year
yearly_crashes = data.groupby(data['CRASH DATE'].dt.year).size()

# Plotting the trend over time by year (Line Graph)
plt.figure(figsize=(12, 6))
yearly_crashes.plot(kind='line', marker='o', color='skyblue', linewidth=2)

# Customize the chart with labels and title
plt.title('Number of Crashes per Year', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Convert 'CRASH DATE' to datetime format
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# Group by month and year to get the number of crashes per month
monthly_crashes = data.groupby(data['CRASH DATE'].dt.to_period("M")).size()

# Plotting the trend over time
plt.figure(figsize=(15, 7))
monthly_crashes.plot()
plt.title('Monthly Trend of Crashes Over Time (2012-2025)', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **LEARN:** What does our graph tell you about the impact of COVID-19 on the number of crashes per month? Why do you think this occurred?
#
# > *  Covid 19 was beyween 2019 and 2021 and during this time as shown in the graph, there was a significant decrease in the number of crashes due to ban of movement, high death rates and unwillingness to go out with the risk of contracting a disease in mind.

# %% [markdown]
# **Step 4**: Apply time series decomposition to review trends, seasonality, and residuals.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# Count the number of crashes per day, group by CRASH DATE
daily_crashes = data.groupby('CRASH DATE').size()

# Set plot style
sns.set(style="darkgrid")

# Plot the daily crashes time series
plt.figure(figsize=(15, 6))
plt.plot(daily_crashes, label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in NYC')
plt.xlabel('Date')
plt.ylabel('Number of Clashes')
plt.legend()
plt.show()

# Decompose the time series
decomposition = seasonal_decompose(daily_crashes, model='additive', period=365)

# Plot the decomposed components
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15, 12))
decomposition.trend.plot(ax=ax1)
ax1.set_title('Trend')
decomposition.seasonal.plot(ax=ax2)
ax2.set_title('Seasonality')
decomposition.resid.plot(ax=ax3)
ax3.set_title('Residuals')
plt.tight_layout()
plt.show()

# %% [markdown]
# The visualizations above provide valuable insights into the time series of daily motor vehicle collisions in New York City:
#
# 1. Time Series Plot: This shows the number of daily crashes over time. You might observe long-term trends, seasonal patterns, or significant outliers.
#
# 2. Decomposed Components:
#
#     2.1 Trend: This graph shows the long-term trend in the data, which can indicate whether crashes are increasing, decreasing, or stable over time.
#
#     2.2 Seasonality: This reveals any regular patterns that repeat over a specific period, such as yearly. It helps identify times of the year with higher or lower crash frequencies.
#
#     2.3 Residuals: These are the irregular components that cannot be attributed to the trend or seasonality. They might include random or unpredictable fluctuations.

# %% [markdown]
# **LEARN:** Based on our *trend graph*, are we seeing an increase or a decrease in crashes between 2014 and 2022?
#
# > *  A decrease.
#
#
# **LEARN:** Based on our *residual graph*, in what year(s) was there a significant unpredicted fluctuation? Why do you think so?
#
# > *  2020 since there was a significant drop in the early months. This fluctuation was unpredicted due to its sudden decrease.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'>**Geospatial Analysis**</font>
# GOAL: The main goal of this session is to explore geospatial aspects of the dataset and get comfortable with regional analysis and geospatial visualizations.

# %% [markdown]
# **Step 1:** et's build a bar chart to compare and analyze the number of crashes across the five boroughs: Brooklyn (also known as Kings County), Queens, Manhattan, Bronx, and Staten Island.

# %%
#Plot a bar chart to compare the number of crashes that occurred in each of the five boroughs.
# Set style
sns.set_style("whitegrid")

# Plotting the distribution of crashes by borough
plt.figure(figsize=(12, 7))
# Find the count of unique values of BOROUGHS. Hint: Use value_count function.
borough_count = data['BOROUGH'].value_counts()
sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")
plt.title('Distribution of Crashes by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-15-4f14068022f4>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")

# %% [markdown]
# **LEARN:** Which borough has the highest number of crashes? Which borough has the lowest?
#
# > * Highest: Brooklyn
# > * Lowest: Staten Island
#
#
# **LEARN:** Are there any reasons that you think a certain borough has a higher or lower number of crashes? What are some factors that may be causing this?
#
# > *  High population and economic reasons like employment.

# %% [markdown]
# **Step 2:** Heatmaps are graphical representations that use color coding to represent different values and variables. Let's leverage a heatmap to determine the most dangerous intersections in the dataset.

# %%
#Create a heatmap leveraging the latitude and longitude variables to determine where the most crashes are occurring
from folium.plugins import HeatMap

# Drop rows with missing latitude and longitude values
data_geo = data.dropna(subset=['LATITUDE', 'LONGITUDE'])

# Create a base map
m = folium.Map(location=[40.730610, -73.935242], zoom_start=10)  # Centered around NYC

# Create a heatmap
heat_data = [[row['LATITUDE'], row['LONGITUDE']] for index, row in data_geo.iterrows()]
HeatMap(heat_data, radius=8, max_zoom=13).add_to(m)

m.save("Heatmap.html")

# %% [markdown]
# **LEARN:**
#
# When looking at our heatmap, where do you see a concentration of crashes?
#
#
# > *  Areas around Midtown and Lower Manhattan as well as Queens and Brooklyn show concentration of clashes.

# %% [markdown]
# **Step 3:** Next, we will begin "Severity Mapping." We'll plot crashes on the map and code them based on severity, distinguishing between crashes that resulted in injuries and those that led to fatalities. This will give us a visual representation of where severe crashes tend to occur. </br>
#
# You may initially want to code these incidents by using different colors, but it's important to think about our map and how accessible it is. Will a color-coded map be easy to read for everyone? Let's make a map that's inclusive for people with color blindness by also creating differently-shaped markers (squares, circles, and triangles) for crashes, injuries, and fatalities.

# %%
# Sample a subset of the data for visualization
data_geo = data.dropna(subset=['LATITUDE', 'LONGITUDE'])
sample_data_severity = data_geo.sample(n=1000, random_state=42)

# Create a base map
m_severity = folium.Map(location=[40.730610, -73.935242], zoom_start=10)

# Add crashes to the map with color coding and shape coding based on severity
for index, row in sample_data_severity.iterrows():
    if row['NUMBER OF PERSONS KILLED'] > 0:
        color = "red"  # Fatalities

        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=3,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


    elif row['NUMBER OF PERSONS INJURED'] > 0:
        color = "blue"  # Injuries
        folium.CircleMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          radius=5,
          color=color,
          fill=True,
          fill_color=color
       ).add_to(m_severity)
    else:
        color = "green"  # No injuries or fatalities
        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=4,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


m_severity.save("severity.html")

# %% [markdown]
# **LEARN** Which intersection(s) seem to be the most dangerous?
#
# > *  Intersections between 5th Avenue and broadway seems damgerous.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ##<font color='crimson'>  **Self-Guided Research Question**</font>
# GOAL: In this session, I will take what I've learned throughout this project, build my own research question, and create a visualization(s) or model(s) to support our research goals.

# %% [markdown]
# **My Research Question:**
# > *  What weather conditions contribute most to severe crashes, and how do these conditions interact with roadway surface conditions and lighting?

# %% [markdown]
# **TO DO:** Build a visualization, model, or use other statistical methods to gain insights into our data and to support our research question.

# %%
#Plot a bar chart to compare the number of crashes that occurred in each of the five boroughs.
# Set style
sns.set_style("whitegrid")

# Plotting the distribution of crashes by borough
plt.figure(figsize=(12, 7))
# Find the count of unique values of BOROUGHS. Hint: Use value_count function.
borough_count = data['BOROUGH'].value_counts()
sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")
plt.title('Distribution of Crashes by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-4f14068022f4>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")

# %%
# Set the visualization style
sns.set_style("whitegrid")

# Group data by borough and sum pedestrian deaths
persons_injured_by_borough = data.groupby('BOROUGH')['NUMBER OF PERSONS INJURED'].sum().reset_index()

# Plotting the data
plt.figure(figsize=(12, 7))
sns.barplot(
    x='BOROUGH',
    y='NUMBER OF PERSONS INJURED',
    data=persons_injured_by_borough,
    palette="viridis"
)

# Customize plot labels and title
plt.title('Number of People Injured by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Number of People Injured', fontsize=14)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-ff8f9b908aee>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Set the visualization style
sns.set_style("whitegrid")

# Group data by borough and sum pedestrian deaths
people_killed_by_borough = data.groupby('BOROUGH')['NUMBER OF PERSONS KILLED'].sum().reset_index()

# Plotting the data
plt.figure(figsize=(12, 7))
sns.barplot(
    x='BOROUGH',
    y='NUMBER OF PERSONS KILLED',
    data=people_killed_by_borough,
    palette="viridis"
)

# Customize plot labels and title
plt.title('Number of People Killed by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Number of People Killed', fontsize=14)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-20-1e36cc443b43>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# Pie Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster


# Convert column names to lowercase for consistency
data.columns = data.columns.str.lower()

# Drop rows with missing borough values
data = data.dropna(subset=['borough'])

# Count crashes per borough
borough_counts = data['borough'].value_counts()

# Pie Chart: Crashes by Borough
plt.figure(figsize=(8, 8))
colors = ['#004830','#006400','#487800','#00AB66','#ACE1AF']
plt.pie(borough_counts, labels=borough_counts.index, autopct='%1.1f%%', colors=colors, startangle=140)
plt.title("Percentage of Crashes by Borough from 2012 to 2025")
plt.show()

# Map: Plot crash locations (only taking a sample for performance)
sample_data = data.dropna(subset=['latitude', 'longitude']).sample(1000, random_state=42)

# %% [markdown]
# Map

# %%
# Create a map centered around NYC
nyc_map = folium.Map(location=[40.7128, -74.0060], zoom_start=11)

# Add crash points
marker_cluster = MarkerCluster().add_to(nyc_map)
for idx, row in sample_data.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=3,
        color='green',
        fill=True,
        fill_color='green',
        fill_opacity=0.7
    ).add_to(marker_cluster)

# Save and display the map
nyc_map.save("nyc_crashes_map.html")
from IPython.display import display
display(nyc_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c04432c417a9bbe6ac5dc41e1d3015a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c04432c417a9bbe6ac5dc41e1d3015a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c04432c417a9bbe6ac5dc41e1d3015a9 = L.map(
#                 &quot;map_c04432c417a9bbe6ac5dc41e1d3015a9&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92e47f9da2efdade9602c545129ae7ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_92e47f9da2efdade9602c545129ae7ff.addTo(map_c04432c417a9bbe6ac5dc41e1d3015a9);
#
#
#             var marker_cluster_b1598abf7331f6aaf35f3de8d3dd511e = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_983f2d0ceff5d0ea417f1cc31c0ba44e = L.circleMarker(
#                 [40.731186, -73.95889],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_b1598abf7331f6aaf35f3de8d3dd511e);
#
#
#             var circle_marker_3807ef50f278cd7f05411f704fac2335 = L.circleMarker(
#                 [40.6545, -73.88222],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_b1598abf7331f6aaf35f3de8d3dd511e);
#
#
#             var circle_marker_124a3fccb1027f3b9b0c1246bfdb8798 = L.circleMarker(
#                 [40.73053, -73.9543],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_b1598abf7331f6aaf35f3de8d3dd511e);
#
#
#             var circle_marker_d759f051bf67cc16d0697215ce2d81bc = L.circleMarker(
#                 [40.743645, -73.94045],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_b1598abf7331f6aaf35f3de8d3dd511e);
#
#
#             var circle_marker_14ae5aad1127cfcda8d16ffdcfe3bc96 = L.circleMarker(
#                 [40.651733, -73.92013],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_b1598abf7331f6aaf35f3de8d3dd511e);
#
#
#             var circle_marker_b8999b20e3c45961905296d876c7ffab = L.circleMarker(
#                 [40.7925479, -73.9410356],
#                 {&quot;bubblingMouse

# %% [markdown]
# ---

# %%
data.columns
# Out:
# Index(['crash date', 'crash time', 'borough', 'zip code', 'latitude',
#        'longitude', 'location', 'on street name', 'cross street name',
#        'off street name', 'number of persons injured',
#        'number of persons killed', 'number of pedestrians injured',
#        'number of pedestrians killed', 'number of cyclist injured',
#        'number of cyclist killed', 'number of motorist injured',
#        'number of motorist killed', 'contributing factor vehicle 1',
#        'contributing factor vehicle 2', 'contributing factor vehicle 3',
#        'contributing factor vehicle 4', 'contributing factor vehicle 5',
#        'collision_id', 'vehicle type code 1', 'vehicle type code 2',
#        'vehicle type code 3', 'vehicle type code 4', 'vehicle type code 5',
#        'hour of day'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Convert column names to lowercase (if not already done)
data.columns = data.columns.str.lower()

# Drop rows with missing borough data
data = data.dropna(subset=['borough'])

# Group data by borough and use lowercase column names in agg
borough_stats = data.groupby('borough').agg(
    total_crashes=('collision_id', 'count'),
    total_injuries=('number of persons injured', 'sum'),
    total_deaths=('number of persons killed', 'sum')
).reset_index()

# Define borough colors
borough_colors = {
    "BROOKLYN": "#004830",
    "MANHATTAN": "#487800",
    "QUEENS": "#006400",
    "BRONX": "#00AB66",
    "STATEN ISLAND": "#ACE1AF"
}

# Bubble Chart
plt.figure(figsize=(12, 7))
ax = sns.scatterplot(
    data=borough_stats,
    x="total_crashes",
    y="total_injuries",
    size="total_deaths",
    hue="borough",
    palette=borough_colors,
    alpha=0.6,
    sizes=(100, 1500),  # Bubble size range
    edgecolor = 'black'
)
for i in range(borough_stats.shape[0]):
    plt.text(
        borough_stats["total_crashes"][i],
        borough_stats["total_injuries"][i],
        borough_stats["borough"][i],
        fontsize=10, ha='right', va='bottom',
        fontweight='bold', color='black'


)
# Chart Labels
plt.xlabel("Total Crashes")
plt.ylabel("Total Injuries")
plt.title("NYC Borough Crashes, Injuries, and Fatalities from 2012 to 2025")
plt.grid(True)

# Show Plot
plt.show()

# %%
borough_stats[['Injured', 'Killed']].sum()
# Out:
# Injured    314129.0
# Killed       1315.0
# dtype: float64

# %%
print(borough_stats)
# Out:
#          borough   Injured  Killed
# 0          BRONX   53826.0   201.0
# 1       BROOKLYN  111998.0   447.0
# 2      MANHATTAN   48213.0   231.0
# 3         QUEENS   88165.0   368.0
# 4  STATEN ISLAND   11927.0    68.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Set visualization style
sns.set_style("whitegrid")

# Ensure 'injured' and 'killed' are numeric
data['number of persons injured'] = pd.to_numeric(data['number of persons injured'], errors='coerce').fillna(0)
data['number of persons killed'] = pd.to_numeric(data['number of persons killed'], errors='coerce').fillna(0)

# Group by borough and sum
borough_stats = data.groupby('borough')[['number of persons injured', 'number of persons killed']].sum().reset_index()

# Rename for clarity
borough_stats.rename(columns={'number of persons injured': 'Injured', 'number of persons killed': 'Killed'}, inplace=True)

# Optionally scale 'Killed' data to enhance visibility (adjust the factor as needed)
borough_stats['Killed_scaled'] = borough_stats['Killed'] * 100  # Scale it by a factor (e.g., 10)

# Define custom colors for 'Injured' and 'Killed' (green and light green)
colors = ['#4CAF50', '#81C784']  # Dark green and light green

# Create stacked bar chart with custom colors
plt.figure(figsize=(12, 7))
ax = borough_stats.set_index('borough')[['Injured', 'Killed_scaled']].plot(kind='bar', stacked=True, color=colors, figsize=(12, 7))

# Customize labels and title
plt.title('Number of People Injured and Killed by Borough from 2012 to 2025', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Category', labels=['Injured', 'Killed'])

# Add the numbers for both Injured and Killed
for container in ax.containers:
    for rect in container:
        height = rect.get_height()  # Get the height of each bar (value)
        width = rect.get_width()  # Get the width of each bar
        x = rect.get_x() + width / 2  # X position for the label (center of the bar)
        y = rect.get_y() + height / 2  # Y position for the label (middle of the bar)

        # Display the correct number, either Injured or Killed
        if rect.get_height() > 0:
            if 'Killed_scaled' in str(rect.get_label()):
                # Display original Killed number
                label = borough_stats.loc[borough_stats['borough'] == rect.get_x(), 'Killed'].values[0]
            else:
                # Display Injured number
                label = int(height)

            ax.text(x, y, f'{int(label)}', ha='center', va='center', fontsize=10, color='black')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style
sns.set_style("whitegrid")

# Convert columns to numeric, handling errors
data['number of persons injured'] = pd.to_numeric(data['number of persons injured'], errors='coerce').fillna(0)
data['number of persons killed'] = pd.to_numeric(data['number of persons killed'], errors='coerce').fillna(0)

# Group by borough and sum
borough_stats = data.groupby('borough')[['number of persons injured', 'number of persons killed']].sum().reset_index()

# Rename for clarity
borough_stats.rename(columns={'number of persons injured': 'Injured', 'number of persons killed': 'Killed'}, inplace=True)

# Optionally scale 'Killed' data to enhance visibility (adjust the factor as needed)
borough_stats['Killed_scaled'] = borough_stats['Killed'] * 10  # Scale it by a factor (e.g., 10)

# Create stacked bar chart with a brighter color map
plt.figure(figsize=(12, 7))
ax = borough_stats.set_index('borough')[['Injured', 'Killed_scaled']].plot(kind='bar', stacked=True, colormap='plasma', figsize=(12, 7))

# Customize labels and title
plt.title('Number of People Injured and Killed by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Category')

# Add the numbers for both Injured and Killed
for container in ax.containers:
    for rect in container:
        height = rect.get_height()  # Get the height of each bar (value)
        width = rect.get_width()  # Get the width of each bar
        x = rect.get_x() + width / 2  # X position for the label (center of the bar)
        y = rect.get_y() + height / 2  # Y position for the label (middle of the bar)

        # Display the correct number, either Injured or Killed
        if rect.get_height() > 0:
            if 'Killed_scaled' in str(rect.get_label()):
                # Display original Killed number
                label = borough_stats.loc[borough_stats['borough'] == rect.get_x(), 'Killed'].values[0]/10
            else:
                # Display Injured number
                label = int(height)

            ax.text(x, y, f'{int(label)}', ha='center', va='center', fontsize=10, color='black')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Set visualization style
sns.set_style("whitegrid")

# Ensure 'injured' and 'killed' are numeric
data['number of persons injured'] = pd.to_numeric(data['number of persons injured'], errors='coerce').fillna(0)
data['number of persons killed'] = pd.to_numeric(data['number of persons killed'], errors='coerce').fillna(0)

# Group by borough and sum
borough_stats = data.groupby('borough')[['number of persons injured', 'number of persons killed']].sum().reset_index()

# Rename for clarity
borough_stats.rename(columns={'number of persons injured': 'Injured', 'number of persons killed': 'Killed'}, inplace=True)

# Create figure and axes
fig, ax1 = plt.subplots(figsize=(12, 7))

# Plot Injured as stacked bars
borough_stats.set_index('borough')['Injured'].plot(kind='bar', stacked=True, color='skyblue', ax=ax1, label='Injured')

# Create secondary y-axis for Killed
ax2 = ax1.twinx()
ax2.plot(borough_stats['borough'], borough_stats['Killed'], marker='o', linestyle='-', color='red', linewidth=2, markersize=8, label='Killed')

# Customize x-axis
ax1.set_xticklabels(borough_stats['borough'], rotation=45)

# Labels and title
ax1.set_xlabel('Borough', fontsize=14)
ax1.set_ylabel('Number of Injured', fontsize=14, color='blue')
ax2.set_ylabel('Number of Killed', fontsize=14, color='red')
plt.title('Number of People Injured and Killed by Borough', fontsize=16)

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 🚗<font color='crimson'> **Thank you for your interest in my project and my learning journey!**</font> 🚗
